# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzalSinghPatel/First-Sem-Data-Science/blob/main/Package_prediction_project_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Library

# %%
import pandas as pd #data manipulation
import numpy as np #mathematics
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation

# %% [markdown]
# Import the data

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA/Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
#find the number of rows and columns
df.shape()
# Out:
# (10000, 6)

# %%
#find the rows from top
df.head(3) #5 by default
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0

# %%
#find the rows from bottom
df.tail(2) #5 by default
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
#find the rows from dataframe randomly
df.sample(7) #1 by default
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 8951              6               86                        Yes            7
# 5321              6               92                         No            4
# 988               3               95                         No            5
# 9236              4               89                        Yes            5
# 2190              1               56                        Yes            4
# 9695              1               67                         No            6
# 6348              7               98                        Yes            7
#
#       Sample Question Papers Practiced  Performance Index
# 8951                                 5               75.0
# 5321                                 9               79.0
# 988                                  1               78.0
# 9236                                 0               69.0
# 2190                                 6               31.0
# ...

# %%
#find the information of the  data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
#how does the data look like mathematically
df.describe() #work's only on numerical data
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
#find the null value in the dataframe
df.isnull().sum() #gives the sum of null values
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
#find the duplicate value
df.duplicated().sum() #gives the sum of duplicate values
# Out:
# 127

# %%
#remove duplicate values
df.drop_duplicates(inplace=True) # inplace=true removes the values directly from the dataframe permanently
